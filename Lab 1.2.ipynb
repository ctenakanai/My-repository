# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (1.18.1)
# Requirement already satisfied: pandas in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/charlesrautenakanai/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("PastHires.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-da765e3c4aef> in <module>
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv("PastHires.csv")
#       5 df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File PastHires.csv does not exist: 'PastHires.csv'

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a393f6b1b242> in <module>
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv("data_assignment.csv")
#       5 df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data_assignment.csv does not exist: 'data_assignment.csv'

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("PastHires.csv")
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
df.size
# Out:
# 1949987

# %%
df.shape
# Out:
# (149999, 13)

# %%
len(df)
# Out:
# 149999

# %%
classificationDF = df[["Classification", "SubClassification"]]
classificationDF = classificationDF.loc[df['Classification'] == "Accounting"]
classificationDF = classificationDF.groupby("Classification")["SubClassification"].value_counts()
classificationDF
# Out:
# Classification  SubClassification
# Accounting      Financial Accounting & Reporting           919
#                 Business Services & Corporate Advisory     805
#                 Accounts Officers/Clerks                   711
#                 Financial Managers & Controllers           674
#                 Payroll                                    530
#                 Accounts Receivable/Credit Control         461
#                 Taxation                                   411
#                 Management Accounting & Budgeting          410
#                 Accounts Payable                           398
#                 Analysis & Reporting                       389
#                 Assistant Accountants                      337
#                 Bookkeeping & Small Practice Accounting    255
#                 Audit - External                           126
#                 Audit - Internal                           121
#                 Other                                      106
#                 Management                                 100
#                 Strategy & Planning                         59
#                 Compliance & Risk                           58
#                 Systems Accounting & IT Audit               49
#                 Treasury                                    44
#                 Insolvency & Corporate Recovery             37
#                 Cost Accounting                             31
#                 Forensic Accounting & Investigation         17
#                 Inventory & Fixed Assets                    17
#                 Company Secretaries                         10
# Name: SubClassification, dtype: int64

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("PastHires.csv")
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
df.shape
# Out:
# (13, 7)

# %%
len(df)
# Out:
# 13

# %%
df.columns
# Out:
# Index(['Years Experience', 'Employed?', 'Previous employers',
#        'Level of Education', 'Top-tier school', 'Interned', 'Hired'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
df.columns
# Out:
# Index(['Id', 'Title', 'Company', 'Date', 'Location', 'Area', 'Classification',
#        'SubClassification', 'Requirement', 'FullDescription', 'LowestSalary',
#        'HighestSalary', 'JobType'],
#       dtype='object')

# %%
df.tail(4)
# Out:
#               Id                       Title                          Company  \
# 149995  37709313          Geology Technician       Saracen Gold Mines Pty Ltd
# 149996  37709312  Lead Product Manager UX/UI       Opus Recruitment Solutions
# 149997  37709253      Junior Primary Teacher  Covenant Christian School (ACT)
# 149998  37709311           Network Engineer            Robert Half Technology
#
#                             Date                            Location  \
# 149995  2018-11-13T00:00:00.000Z  Kalgoorlie, Goldfields & Esperance
# 149996  2018-11-13T00:00:00.000Z                           Melbourne
# 149997  2018-11-13T00:00:00.000Z                                 ACT
# 149998  2018-11-13T00:00:00.000Z                               Perth
#
#                                 Area                          Classification  \
# 149995                           NaN              Mining, Resources & Energy
# 149996           CBD & Inner Suburbs                   Design & Architecture
# 149997                           NaN                    Education & Training
# 149998  CBD, Inner & Western Suburbs  Information & Communication Technology
#
#                         SubClassification  \
# 149995  Mining - Exploration & Geoscience
# 149996                     Graphic Design
# 149997                 Teaching - Primary
# 149998              Engineering - Network
#
#                                               Requirement  \
# 149995  Due to an increase in our Exploration budget, ...
# 149996  Senior Lead Product Manager | UX/UI | Payment/...
# 149997  Junior Primary teacher to take a small single ...
# 149998  Our client requires an experienced Network Eng...
#
#                                           FullDescription  LowestSalary  \
# 149995  <p style="text-align:justify;">Saracen Mineral...             0
# 149996  One Australia’s leading online payments platfo...             0
# 149997  <p><strong>Junior Primary Teacher (part time o...             0
# 149998  <ul>\n          <li><strong>Permanent Position...             0
#
#         HighestSalary    JobType
# 149995             30  Full Time
# 149996             30  Full Time
# 149997             30  Full Time
# 149998             30  Full Time

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
degree_counts = df('Level of Education').value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7aa5860cdf4f> in <module>
# ----> 1 degree_counts = df('Level of Education').value_counts()
#
# TypeError: 'DataFrame' object is not callable

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.read_csv("PastHires.csv")
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
degree_counts = df['Level of Education'].value_counts()
degree_counts
# Out:
# BS     7
# PhD    4
# MS     2
# Name: Level of Education, dtype: int64

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.read_csv("data_assignment.csv")
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
degree_counts = df['Location'].value_counts()
degree_counts
# Out:
# Sydney                                  46357
# Melbourne                               35315
# Brisbane                                16538
# Perth                                    9913
# Adelaide                                 4998
#                                         ...
# Coober Pedy & Outback SA                   78
# Tumut, Snowy & Monaro                      69
# Somerset & Lockyer                         56
# Fleurieu Peninsula & Kangaroo Island       53
# Central & South East TAS                   36
# Name: Location, Length: 65, dtype: int64

# %%
df.shape
df.columns
df['Classification']
degree_counts = df['Classification'].value_counts()
degree_counts
# Out:
# Information & Communication Technology    16661
# Trades & Services                         14125
# Healthcare & Medical                      12515
# Hospitality & Tourism                     11818
# Manufacturing, Transport & Logistics       9608
# Administration & Office Support            7636
# Accounting                                 7075
# Education & Training                       7033
# Retail & Consumer Products                 6496
# Sales                                      6281
# Construction                               6254
# Government & Defence                       5926
# Engineering                                4812
# Mining, Resources & Energy                 4679
# Community Services & Development           3528
# Banking & Financial Services               3481
# Human Resources & Recruitment              3233
# Call Centre & Customer Service             3127
# Legal                                      3071
# Marketing & Communications                 3052
# Real Estate & Property                     2729
# Design & Architecture                      1379
# Insurance & Superannuation                 1144
# Consulting & Strategy                       905
# Sport & Recreation                          750
# Science & Technology                        696
# Farming, Animals & Conservation             683
# Advertising, Arts & Media                   644
# CEO & General Management                    585
# Self Employment                              73
# Name: Classification, dtype: int64

# %%
classificationDF = df[["Classification", "SubClassification"]]
classificationDF = classificationDF.loc[df['Classification'] == "Mining, Resources & Energy"]
classificationDF = classificationDF.groupby("Classification")["SubClassification"].value_counts()
classificationDF
# Out:
# Classification              SubClassification
# Mining, Resources & Energy  Mining - Engineering & Maintenance       1612
#                             Mining - Operations                      1110
#                             Other                                     308
#                             Health, Safety & Environment              249
#                             Mining - Exploration & Geoscience         209
#                             Management                                187
#                             Mining - Drill & Blast                    177
#                             Mining - Processing                       174
#                             Power Generation & Distribution           173
#                             Oil & Gas - Engineering & Maintenance     144
#                             Oil & Gas - Operations                    115
#                             Analysis & Reporting                       98
#                             Surveying                                  39
#                             Oil & Gas - Drilling                       27
#                             Natural Resources & Water                  20
#                             Oil & Gas - Production & Refinement        19
#                             Oil & Gas - Exploration & Geoscience       18
# Name: SubClassification, dtype: int64

# %%
df.shape
df.columns
df['JobType']
degree_counts = df['JobType'].value_counts()
degree_counts
# Out:
# Full Time          96410
# Contract/Temp      26238
# Casual/Vacation    13496
# Part Time          10622
# Name: JobType, dtype: int64

# %%
df[df.duplicated()].shape[0]
# Out:
# 0

# %%
df.dtypes
# Out:
# Id                    int64
# Title                object
# Company              object
# Date                 object
# Location             object
# Area                 object
# Classification       object
# SubClassification    object
# Requirement          object
# FullDescription      object
# LowestSalary          int64
# HighestSalary         int64
# JobType              object
# dtype: object

# %%
df['Id'] = pd.to_numeric(df['Id'])
df.dtypes
# Out:
# Id                                 int64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                       int64
# HighestSalary                      int64
# JobType                           object
# dtype: object

# %%
df["Date"] = df["Date"].replace(to_replace=r'T.*', value='', regex=True)
df["Date"] = pd.to_datetime(df["Date"])

df.dtypes

df.sort_values(['HighestSalary'])
# Out:
#               Id                                              Title  \
# 0       37404348                           Casual Stock Replenisher
# 67018   37520161                        TECHNICAL BUSINESS ANALYST!
# 67019   37520159  NETWORK ENGINEER - Wintel, Linux, Cisco, Junip...
# 67020   37520160        MANAGED SERVICES ENGINEER - Projects + BAU!
# 67021   37520158             Immediate Start - Events & Kiosk Sales
# ...          ...                                                ...
# 113640  37526143                                    UX UI Designers
# 113639  37526174  Contract Administrator | Mid Tier - Commercial...
# 113638  37526178  Project Management and Engagement Specialist (...
# 113658  37525546                        Channel Sales Manager (GPO)
# 112990  37547158                               Full Stack Developer
#
#                        Company                      Date   Location  \
# 0                  Aldi Stores 2018-10-07 00:00:00+00:00     Sydney
# 67018         Saul Recruitment 2018-10-21 00:00:00+00:00     Sydney
# 67019         Saul Recruitment 2018-10-21 00:00:00+00:00  Melbourne
# 67020         Saul Recruitment 2018-10-21 00:00:00+00:00     Sydney
# 67021               My Joblist 2018-10-21 00:00:00+00:00      Perth
# ...                        ...                       ...        ...
# 113640       Alchemy Solutions 2018-10-22 00:00:00+00:00  Melbourne
# 113639  James Scott JoB Search 2018-10-22 00:00:00+00:00     Sydney
# 113638     TRS - Public Sector 2018-10-22 00:00:00+00:00     Sydney
# 113658               CommScope 2018-10-22 00:00:00+00:00  Melbourne
# 112990                     LPS 2018-10-24 00:00:00+00:00  Melbourne
#
#                                        Area  \
# 0               North West & Hills District
# 67018                                   NaN
# 67019                                   NaN
# 67020     CBD, Inner West & Eastern Suburbs
# 67021          CBD, Inner & Western Suburbs
# ...                                     ...
# 113640                  CBD & Inner Suburbs
# 113639  Southern Suburbs & Sutherland Shire
# 113638    CBD, Inner West & Eastern Suburbs
# 113658                                  NaN
# 112990                      Eastern Suburbs
#
#                                 Classification  \
# 0                   Retail & Consumer Products
# 67018   Information & Communication Technology
# 67019   Information & Communication Technology
# 67020   Information & Communication Technology
# 67021               Retail & Consumer Products
# ...                                        ...
# 113640                   Design & Architecture
# 113639                            Construction
# 113638  Information & Communication Technology
# 113658                                   Sales
# 112990  Information & Communication Technology
#
#                         SubClassification  \
# 0                       Retail Assistants
# 67018           Business/Systems Analysts
# 67019               Engineering - Network
# 67020   Networks & Systems Administration
# 67021                   Retail Assistants
# ...                                   ...
# 113640           Web & Interaction Design
# 113639               Contracts Management
# 113638     Programme & Project Management
# 113658           New Business Development
# 112990             Developers/Programmers
#
#                                               Requirement  \
# 0       Our Casual Stock Replenishers pride themselves...
# 67018   Established and ever-growing IT software solut...
# 67019   Global player working with some of Australia's...
# 67020   Very reputable IT Services organisation! Stron...
# 67021   After recent expansion to Perth, Unite is look...
# ...                                                   ...
# 113640  We are seeking experienced User Experience / U...
# 113639  Mid-Tier Head-Contractor | Location: Southern ...
# 113638  Project Management & Engagement Specialist (2 ...
# 113658  Seek to position CommScope as a strategic part...
# 112990  We are looking for an experienced developer to...
#
#                                           FullDescription  LowestSalary  \
# 0                                                     NaN             0
# 67018   <ul>\n            <li><strong>Master Data Mana...             0
# 67019   <br>\n          <ul>\n            <li><strong>...             0
# 67020   <br>\n          <ul>\n            <li><strong>...             0
# 67021   <p>Due to client demand, Unite is looking for ...             0
# ...                                                   ...           ...
# 113640  <p> </p><p><strong>About the business</strong>...           200
# 113639  <ul>\n          <li>Contract Administrator: Up...           200
# 113638  <p style="text-align:center;"><strong>Project ...           200
# 113658  <p><strong>Responsibilities:</strong></p> <ul>...           200
# 112990  <p>LPS is a Delivery and Transformation Servic...           200
#
#         HighestSalary        JobType
# 0                  30            NaN
# 67018              30      Full Time
# 67019              30      Full Time
# 67020              30      Full Time
# 67021              30  Contract/Temp
# ...               ...            ...
# 113640            250  Contract/Temp
# 113639            250      Full Time
# 113638            250  Contract/Temp
# 113658            250      Full Time
# 112990            250  Contract/Temp
#
# [149999 rows x 13 columns]

# %%
df['HighestSalary']
degree_counts = df['HighestSalary'].value_counts()
degree_counts
# Out:
# 30     27606
# 50     17708
# 70     14108
# 120    13062
# 80     12932
# 100    12582
# 60     12559
# 40     12441
# 200    11738
# 150    10651
# 250     4612
# Name: HighestSalary, dtype: int64

# %%
df['LowestSalary']
degree_counts = df['LowestSalary'].value_counts()
degree_counts
# Out:
# 0      27606
# 40     17708
# 60     14108
# 100    13062
# 70     12932
# 80     12582
# 50     12559
# 30     12441
# 150    11738
# 120    10651
# 200     4612
# Name: LowestSalary, dtype: int64
